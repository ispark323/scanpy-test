# %%
# !pip install scanpy

# %%
import scanpy as sc
import pandas as pd
import numpy as np

# %%
#need to install these too
# !conda install -y -c anaconda cmake 
# !pip install leidenalg
# !pip install louvain

# %%
#easy to follow tutorial on scanpy readthedocs
#https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html

# %%
#tutorial_sample was the dir created by cellranger based on our flag: --id tutorial_sample

adata = sc.read_10x_mtx(
    'filtered_gene_bc_matrices/hg19',  # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)                              # write a cache file for faster subsequent reading

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %% [markdown]
# # Preprocessing

# %%
sc.pp.filter_cells(adata, min_genes=200) #get rid of cells with fewer than 200 genes
sc.pp.filter_genes(adata, min_cells=3) #get rid of genes that are found in fewer than 3 cells

# %%
#IF YOU ARE DOING MOUSE YOU MIGHT NEED TO CHANGE MT- to Mt. Always double check you actually labeld MT
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'

# %%
adata.var
# Out:
#                       gene_ids  n_cells     mt
# AL627309.1     ENSG00000237683        9  False
# AP006222.2     ENSG00000228463        3  False
# RP11-206L10.2  ENSG00000228327        5  False
# RP11-206L10.9  ENSG00000237491        3  False
# LINC00115      ENSG00000225880       18  False
# ...                        ...      ...    ...
# AC145212.1     ENSG00000215750       16  False
# AL592183.1     ENSG00000220023      323  False
# AL354822.1     ENSG00000215615        8  False
# PNRC2-1        ENSG00000215700      110  False
# SRSF10-1       ENSG00000215699       69  False
#
# [13714 rows x 3 columns]

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 13714
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata.obs
# Out:
#                   n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACATACAACCAC-1      781                779        2419.0             73.0
# AAACATTGAGCTAC-1     1352               1352        4903.0            186.0
# AAACATTGATCAGC-1     1131               1129        3147.0             28.0
# AAACCGTGCTTCCG-1      960                960        2639.0             46.0
# AAACCGTGTATGCG-1      522                521         980.0             12.0
# ...                   ...                ...           ...              ...
# TTTCGAACTCTCAT-1     1155               1153        3459.0             73.0
# TTTCTACTGAGGCA-1     1227               1224        3443.0             32.0
# TTTCTACTTCCTCG-1      622                622        1684.0             37.0
# TTTGCATGAGAGGC-1      454                452        1022.0             21.0
# TTTGCATGCCTCAC-1      724                723        1984.0             16.0
#
#                   pct_counts_mt
# AAACATACAACCAC-1       3.017776
# AAACATTGAGCTAC-1       3.793596
# AAACATTGATCAGC-1       0.889736
# AAACCGTGCTTCCG-1       1.743085
# AAACCGTGTATGCG-1       1.224490
# ...                         ...
# TTTCGAACTCTCAT-1       2.110436
# TTTCTACTGAGGCA-1       0.929422
# TTTCTACTTCCTCG-1       2.197150
# TTTGCATGAGAGGC-1       2.054795
# TTTGCATGCCTCAC-1       0.806452
#
# [2700 rows x 5 columns]

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], jitter=0.4, multi_panel=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], jitter=0.4, multi_panel=True)
# Out:
# /home/jrlab2019/miniconda3/envs/geo/lib/python3.10/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'feature_types' as categorical

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
#instead of picking subjectively, you can use quanitle
upper_lim = np.quantile(adata.obs.n_genes_by_counts.values, .98)
lower_lim = np.quantile(adata.obs.n_genes_by_counts.values, .02)
print(f'{lower_lim} to {upper_lim}')
# Out:
# 361.94 to 1571.2199999999998

# %%
adata[adata.obs.index == 'AAACCCAAGCCTGTGC-1']
# Out:
# View of AnnData object with n_obs × n_vars = 0 × 13714
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
#adata = adata[adata.obs.n_genes_by_counts < 7000, :] #example if you wanted to pick a number yourself
adata = adata[(adata.obs.n_genes_by_counts < upper_lim) & (adata.obs.n_genes_by_counts > lower_lim)]
adata = adata[adata.obs.pct_counts_mt < 20]

# %%
adata.X[1,:].sum()
# Out:
# 4903.0

# %%
sc.pp.normalize_total(adata, target_sum=1e4) #normalize every cell to 10,000 UMI
# Out:
# c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\scanpy\preprocessing\_normalization.py:207: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
adata.X[0,:].sum()
# Out:
# 9999.966

# %%
sc.pp.log1p(adata) #change to log counts

# %% [markdown]
# # Clustering

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5) #these are default values

# %%
adata.raw = adata #save raw data before processing values and further filtering

# %%
adata = adata[:, adata.var.highly_variable] #filter highly variable

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt']) #Regress out effects of total counts per cell and the percentage of mitochondrial genes expressed
# Out:
# c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\scanpy\preprocessing\_simple.py:657: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.scale(adata, max_value=10) #scale each gene to unit variance

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=20)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata)

# %%
sc.tl.leiden(adata, resolution = 0.25)
sc.pl.umap(adata, color=['leiden'])
# Out:
# C:\Users\spark\AppData\Local\Temp\ipykernel_28156\3712666207.py:1: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution = 0.25)

# %% [markdown]
# # Find markers

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)

# %%
sc.pl.umap(adata, color=['leiden', 'zika'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zika'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sc.pl.umap(adata, color=['leiden', 'zika'])
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:690, in umap(adata, **kwargs)
#     631 @_wraps_plot_scatter
#     632 @_doc_params(
#     633     adata_color_etc=doc_adata_color_etc,
#    (...)
#     637 )
#     638 def umap(adata: AnnData, **kwargs) -> Figure | Axes | list[Axes] | None:
#     639     """\
#     640     Scatter plot in UMAP basis.
#     641
#    (...)
#     688     tl.umap
#     689     """
# --> 690     return embedding(adata, "umap", **kwargs)
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:278, in embedding(adata, basis, color, mask_obs, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, marker, **kwargs)
#     276 for count, (value_to_plot, dims) in enumerate(zip(color, dimensions)):
#     277     kwargs_scatter = kwargs.copy()  # is potentially mutated for each plot
# --> 278     color_source_vector = _get_color_source_vector(
#     279         adata,
#     280         value_to_plot,
#     281         layer=layer,
#     282         mask_obs=mask_obs,
#     283         use_raw=use_raw,
#     284         gene_symbols=gene_symbols,
#     285         groups=groups,
#     286     )
#     287     color_vector, color_type = _color_vector(
#     288         adata,
#     289         value_to_plot,
#    (...)
#     292         na_color=na_color,
#     293     )
#     295     # Order points
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1201, in _get_color_source_vector(adata, value_to_plot, mask_obs, use_raw, gene_symbols, layer, groups)
#    1199     value_to_plot = adata.var.index[adata.var[gene_symbols] == value_to_plot][0]
#    1200 if use_raw and value_to_plot not in adata.obs.columns:
# -> 1201     values = adata.raw.obs_vector(value_to_plot)
#    1202 else:
#    1203     values = adata.obs_vector(value_to_plot, layer=layer)
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\anndata\_core\raw.py:191, in Raw.obs_vector(self, k)
#     189 def obs_vector(self, k: str) -> np.ndarray:
#     190     # TODO decorator to copy AnnData.obs_vector docstring
# --> 191     idx = self._normalize_indices((slice(None), k))
#     192     a = self.X[idx]
#     193     if issparse(a):
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\anndata\_core\raw.py:182, in Raw._normalize_indices(self, packed_index)
#     180 obs, var = unpack_index(packed_index)
#     181 obs = _normalize_index(obs, self._adata.obs_names)
# --> 182 var = _normalize_index(var, self.var_names)
#     183 return obs, var
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\anndata\_core\index.py:73, in _normalize_index(indexer, index)
#      71     return indexer
#      72 elif isinstance(indexer, str):
# ---> 73     return index.get_loc(indexer)  # int
#      74 elif isinstance(indexer, (Sequence, np.ndarray, pd.Index, spmatrix, np.matrix)):
#      75     if hasattr(indexer, "shape") and (
#      76         (indexer.shape == (index.shape[0], 1))
#      77         or (indexer.shape == (1, index.shape[0]))
#      78     ):
#
# File c:\Users\spark\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'zika'

# %%
results = adata.uns['rank_genes_groups']

# %%
results['names']['0']
# Out:
# array(['KCNQ1OT1', 'HIST1H4C', 'HIST1H1E', ..., 'LDHA', 'CKS2', 'RPL36'],
#       dtype=object)

# %%
results['names'].dtype.names
# Out:
# ('0', '1', '2', '3', '4')

# %%
out = np.array([[0,0,0,0,0]])
for group in results['names'].dtype.names:
    out = np.vstack((out, np.vstack((results['names'][group],
                                     results['scores'][group],
                                     results['pvals_adj'][group],
                                     results['logfoldchanges'][group],
                                     np.array([group] * len(results['names'][group])).astype('object'))).T))

# %%
out.shape
# Out:
# (109746, 5)

# %%
markers = pd.DataFrame(out[1:], columns = ['Gene', 'scores', 'pval_adj', 'lfc', 'cluster'])

# %%
markers = markers[(markers.pval_adj < 0.05) & (abs(markers.lfc) > 1)]

# %%
markers[markers.cluster == '4']
# Out:
#             Gene     scores pval_adj       lfc cluster
# 87796       zika  23.704487      0.0  8.062958       4
# 87797     SNHG15  16.631556      0.0  1.818314       4
# 87798     SDF2L1  16.453564      0.0  1.920571       4
# 87799       XBP1  16.216284      0.0  1.708001       4
# 87800   EIF4EBP1  15.350019      0.0  1.237626       4
# ...          ...        ...      ...       ...     ...
# 109739      SOX4 -13.782868      0.0 -1.743386       4
# 109740      PGK1 -13.823959      0.0 -1.340903       4
# 109741     MSMO1 -13.977442      0.0 -2.380198       4
# 109743   SLC25A3 -16.256285      0.0 -1.478398       4
# 109744      XIST -16.642595      0.0 -1.296944       4
#
# [396 rows x 5 columns]

# %%
adata.raw.var_names
# Out:
# Index(['AL627309.1', 'AL627309.5', 'LINC01409', 'FAM87B', 'LINC01128',
#        'LINC00115', 'FAM41C', 'AL645608.2', 'AL645608.4', 'LINC02593',
#        ...
#        'MT-CYB', 'BX004987.1', 'AC145212.1', 'MAFIP', 'AC011043.1',
#        'AL354822.1', 'AL592183.1', 'AC240274.1', 'AC007325.4', 'zika'],
#       dtype='object', length=21949)

# %%
zik_i = np.where(adata.raw.var_names == 'zika')[0][0]
zik_i
# Out:
# 21948

# %%
zik = adata.raw.X.toarray()[:,zik_i]

# %%
adata.obs['zika'] = zik

# %%
adata.obs['Zika'] = zik

# %%
adata.obs[adata.obs.zika > 0 ]
# Out:
#                     n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCCAAGTATAGAC-1     5443               5443       25977.0           1477.0
# AAACCCACAACGCATT-1     5159               5159       21172.0           1035.0
# AAACCCACACGCGCAT-1     5991               5991       26725.0           1724.0
# AAACCCAGTGCATTAC-1     4657               4656       17707.0            678.0
# AAACCCAGTTACGCCG-1     3704               3704       11699.0            539.0
# ...                     ...                ...           ...              ...
# TTTGGTTCACCATAAC-1     3452               3450       11069.0            668.0
# TTTGTTGAGATCCGAG-1     4330               4330       16295.0            378.0
# TTTGTTGAGGCACAAC-1     5052               5051       17574.0            891.0
# TTTGTTGAGTCACACT-1     3281               3281        9758.0            370.0
# TTTGTTGGTCGTCTCT-1     4111               4111       14611.0            631.0
#
#                     pct_counts_mt leiden      zika
# AAACCCAAGTATAGAC-1       5.685799      1  0.325668
# AAACCCACAACGCATT-1       4.888532      2  0.386841
# AAACCCACACGCGCAT-1       6.450889      2  5.798806
# AAACCCAGTGCATTAC-1       3.828994      2  0.755886
# AAACCCAGTTACGCCG-1       4.607232      0  0.617763
# ...                           ...    ...       ...
# TTTGGTTCACCATAAC-1       6.034873      0  1.032062
# TTTGTTGAGATCCGAG-1       2.319730      0  0.478521
# TTTGTTGAGGCACAAC-1       5.069990      2  0.450453
# TTTGTTGAGTCACACT-1       3.791761      0  0.705471
# TTTGTTGGTCGTCTCT-1       4.318664      0  4.436737
#
# [3335 rows x 7 columns]

# %%
sc.pl.violin(adata, ['Zika', 'CDKN2A'], groupby='leiden', use_raw = True)
